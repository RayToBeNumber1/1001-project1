# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ks_2samp

# %%
df = pd.read_csv('movieReplicationSet.csv')

# %%
len(df)
# Out:
# 1097

# %%
home = df['Home Alone (1990)']
finding = df['Finding Nemo (2003)']

# %%
home = home.dropna()
finding = finding.dropna()

# %%
statistic, p_value = ks_2samp(home, finding)

# %%
p_value
# Out:
# 6.379397182836346e-10

# %%
# 创建示例数据


# 绘制直方图
plt.hist(home, density =True ,bins = 4)
plt.xlabel('Home Alone(1990)')
plt.ylabel('Frequency')

plt.show()

# %%
plt.hist(finding, density=True, bins = 4)
plt.xlabel('Finding Nemo (2003)')
plt.ylabel('Frequency')

plt.show()

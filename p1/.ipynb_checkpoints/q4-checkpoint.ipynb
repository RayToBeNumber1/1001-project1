# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('movieReplicationSet.csv')
df
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                            3.0                    4.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                         4.0           NaN
# 1                         1.5           NaN
# 2                         NaN           NaN
# 3                         2.0           NaN
# ...

# %%
df.columns[474]
# Out:
# 'Gender identity (1 = female; 2 = male; 3 = self-described)'

# %%
gender_col = df['Gender identity (1 = female; 2 = male; 3 = self-described)']

# %%
gender_col
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 1092    1.0
# 1093    1.0
# 1094    1.0
# 1095    1.0
# 1096    1.0
# Name: Gender identity (1 = female; 2 = male; 3 = self-described), Length: 1097, dtype: float64

# %%
gender_col.value_counts()
# Out:
# Gender identity (1 = female; 2 = male; 3 = self-described)
# 1.0    807
# 2.0    260
# 3.0      6
# Name: count, dtype: int64

# %%
male = gender_col[gender_col == 2].index
female = gender_col[gender_col == 1].index

# %%
movie_male = df.iloc[male,0:400]
movie_male
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 9                               NaN                    NaN
# 13                              NaN                    NaN
# 15                              NaN                    NaN
# 17                              NaN                    NaN
# 19                              NaN                    NaN
# ...                             ...                    ...
# 1082                            NaN                    NaN
# 1084                            NaN                    NaN
# 1088                            NaN                    NaN
# 1089                            NaN                    NaN
# 1090                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 9                         NaN           3.0
# 13                        NaN           NaN
# 15                        2.0           NaN
# 17                        NaN           NaN
# ...

# %%
movie_female = df.iloc[female, 0:400]
movie_female
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                            3.0                    4.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                         4.0           NaN
# 1                         1.5           NaN
# 2                         NaN           NaN
# 3                         2.0           NaN
# ...

# %%
count = 0
for i in movie_male.columns:

    t_stat, p_value = ttest_ind(movie_male[i], movie_female[i], nan_policy='omit')
    if p_value <= 0.005:
        count += 1
print(count/400)

print(count)
# Out:
# 0.115
# 46
